# %% [markdown]
# # Practicing queries: Deliverable 4

# %% [markdown]
# ## SQLite installation

# %%
import sqlite3

# %% [markdown]
# ## Mount Drive and set path
# n the left-hand side menu, we select the folder, then click on the "drive" folder and follow the corresponding steps.
#
# Afterward, we look for our folder and copy the path of the one containing all the files we are working on, and include that path as the DRIVE_PATH variable.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Importing the database

# %%
con = sqlite3.connect("/content/drive/MyDrive/eada material/classic.db")
#ltcursor = con.cursor()

# %% [markdown]
# ## All the questions are related to the classicmodels database

# %% [markdown]
# 1. List those customers whose first order had a value of more than €30,000.

# %%
q="""
SELECT customerName
FROM customers
WHERE customerNumber IN(
  SELECT customerNumber
  FROM orders
  WHERE orderNumber IN(
    SELECT MIN(orderNumber)
    FROM orders
    GROUP BY customerNumber
  )
AND orderNumber IN(
  SELECT orderNumber
  FROM orderdetails
  GROUP BY orderNumber
  HAVING SUM(priceEach*quantityOrdered)>30000
)
)
"""
pd.read_sql(q,con)
# Out:
#                           customerName
# 0                   Signal Gift Stores
# 1           Australian Collectors, Co.
# 2                    La Rochelle Gifts
# 3                   Baane Mini Imports
# 4               Euro+ Shopping Channel
# 5             Danish Wholesale Imports
# 6               Saveley & Henriot, Co.
# 7              Dragon Souveniers, Ltd.
# 8                   Muscle Machine Inc
# 9                 Technics Stores Inc.
# 10                        Herkku Gifts
# 11            Daedalus Designs Imports
# 12           La Corne D'abondance, Co.
# 13                Osaka Souveniers Co.
# 14                Toys of Finland, Co.
# 15                      AV Stores, Co.
# 16             Clover Collections, Co.
# 17               UK Collectables, Ltd.
# 18      Canadian Gift Exchange Network
# 19            Online Mini Collectables
# 20                   Toys4GrownUps.com
# 21                         Mini Caravy
# 22                Heintze Collectables
# ...

# %%
q="""
SELECT customerName
FROM customers
WHERE customerNumber IN(
  SELECT customerNumber
  FROM orders
  WHERE orderNumber IN(
    SELECT MIN(orderNumber)
    FROM orders
    GROUP BY customerNumber
)
AND orderNumber IN(
  SELECT orderNumber
  FROM orderdetails
  GROUP BY orderNumber
  HAVING SUM(priceEach*quantityOrdered)>30000)
)"""
pd.read_sql(q,con)
# Out:
#                           customerName
# 0                   Signal Gift Stores
# 1           Australian Collectors, Co.
# 2                    La Rochelle Gifts
# 3                   Baane Mini Imports
# 4               Euro+ Shopping Channel
# 5             Danish Wholesale Imports
# 6               Saveley & Henriot, Co.
# 7              Dragon Souveniers, Ltd.
# 8                   Muscle Machine Inc
# 9                 Technics Stores Inc.
# 10                        Herkku Gifts
# 11            Daedalus Designs Imports
# 12           La Corne D'abondance, Co.
# 13                Osaka Souveniers Co.
# 14                Toys of Finland, Co.
# 15                      AV Stores, Co.
# 16             Clover Collections, Co.
# 17               UK Collectables, Ltd.
# 18      Canadian Gift Exchange Network
# 19            Online Mini Collectables
# 20                   Toys4GrownUps.com
# 21                         Mini Caravy
# 22                Heintze Collectables
# ...

# %% [markdown]
# 2. List the first name and last name of each manager followed by the first name and last name of each employee they supervise. Sort the results by the last name of each manager.

# %%
q="""
WITH manager AS(
  SELECT employeeNumber, lastName,firstName, jobTitle
  FROM employees
  WHERE jobTitle LIKE ("%MANAGER%")
)
SELECT e.employeeNumber, e.lastName, e.firstName, e.reportsTo, m.firstName, m.lastName
FROM employees e
INNER JOIN manager m ON e.reportsTo=m.employeeNumber
ORDER BY m.lastname DESC
"""
pd.read_sql(q,con)
# Out:
#     employeeNumber   lastName firstName reportsTo firstName   lastName
# 0             1611     Fixter      Andy      1088   William  Patterson
# 1             1612      Marsh     Peter      1088   William  Patterson
# 2             1619       King       Tom      1088   William  Patterson
# 3             1165   Jennings    Leslie      1143   Anthony        Bow
# 4             1166   Thompson    Leslie      1143   Anthony        Bow
# 5             1188   Firrelli     Julie      1143   Anthony        Bow
# 6             1216  Patterson     Steve      1143   Anthony        Bow
# 7             1286      Tseng  Foon Yue      1143   Anthony        Bow
# 8             1323     Vanauf    George      1143   Anthony        Bow
# 9             1337     Bondur      Loui      1102    Gerard     Bondur
# 10            1370  Hernandez    Gerard      1102    Gerard     Bondur
# 11            1401   Castillo    Pamela      1102    Gerard     Bondur
# ...

# %%
q="""
WITH manager AS(
SELECT employeeNumber, lastName, firstName,jobTitle
FROM employees
WHERE jobTitle LIKE ("%MANAGER%")
)
SELECT e.lastName, e.firstName, e.reportsTo, m.lastName, m.firstName
FROM employees e
INNER JOIN manager m ON e.reportsTo=m.employeeNumber
ORDER BY m.lastName DESC"""
pd.read_sql(q,con)
# Out:
#      lastName firstName reportsTo   lastName firstName
# 0      Fixter      Andy      1088  Patterson   William
# 1       Marsh     Peter      1088  Patterson   William
# 2        King       Tom      1088  Patterson   William
# 3    Jennings    Leslie      1143        Bow   Anthony
# 4    Thompson    Leslie      1143        Bow   Anthony
# 5    Firrelli     Julie      1143        Bow   Anthony
# 6   Patterson     Steve      1143        Bow   Anthony
# 7       Tseng  Foon Yue      1143        Bow   Anthony
# 8      Vanauf    George      1143        Bow   Anthony
# 9      Bondur      Loui      1102     Bondur    Gerard
# 10  Hernandez    Gerard      1102     Bondur    Gerard
# 11   Castillo    Pamela      1102     Bondur    Gerard
# 12       Bott     Larry      1102     Bondur    Gerard
# 13      Jones     Barry      1102     Bondur    Gerard
# 14     Gerard    Martin      1102     Bondur    Gerard

# %% [markdown]
# 3. List the names of the top 10 customers with the greatest number orders, considering only those who have spent more than €10,000 in the total of their orders.

# %%
q = """
WITH filteredCustomers AS(SELECT SUM(od.priceEach*od.quantityOrdered) AS TotalMoney, customerNumber
FROM orderdetails od
INNER JOIN orders o ON od.orderNumber=o.orderNumber
GROUP BY customerNumber
HAVING TotalMoney>10000)

SELECT c.customerName, fc.TotalMoney
FROM filteredCustomers fc
INNER JOIN customers c ON fc.customerNumber=c.customerNumber
ORDER BY fc.TotalMoney DESC LIMIT 10;
"""

pd.read_sql(q,con)
# Out:
#                    customerName  TotalMoney
# 0        Euro+ Shopping Channel   820689.54
# 1  Mini Gifts Distributors Ltd.   591827.34
# 2    Australian Collectors, Co.   180585.07
# 3            Muscle Machine Inc   177913.95
# 4             La Rochelle Gifts   158573.12
# 5       Dragon Souveniers, Ltd.   156251.03
# 6    Down Under Souveniers, Inc   154622.08
# 7             Land of Toys Inc.   149085.15
# 8                AV Stores, Co.   148410.09
# 9     The Sharp Gifts Warehouse   143536.27

# %% [markdown]
# 4. List the top 3 countries with the most units of product sold.

# %%
q="""
WITH countrys AS(
  SELECT c.country, SUM(quantityordered) unitssold
  FROM orderdetails od
  INNER JOIN orders o ON od.orderNumber=o.orderNumber
  INNER JOIN customers c ON o.customerNumber=c.customerNumber
  GROUP BY c.country)
SELECT country, unitssold
FROM countrys
ORDER BY unitssold DESC
LIMIT 3"""
pd.read_sql(q,con)
# Out:
#   country  unitssold
# 0     USA      35844
# 1   Spain      12429
# 2  France      11090

# %%
q = """
WITH CountrySales AS (
    SELECT
        c.country,
        SUM(od.quantityOrdered) AS totalUnitsSold
    FROM orderdetails od
    INNER JOIN orders o ON od.orderNumber = o.orderNumber
    INNER JOIN customers c ON o.customerNumber = c.customerNumber
    GROUP BY c.country
)
SELECT country, totalUnitsSold
FROM CountrySales
ORDER BY totalUnitsSold DESC
LIMIT 3
"""

# Execute the query and fetch the result
pd.read_sql(q, con)
# Out:
#   country  totalUnitsSold
# 0     USA           35844
# 1   Spain           12429
# 2  France           11090

# %% [markdown]
# 5. How many customers have placed more than one order on the same day?

# %%
q="""
SELECT o.customerNumber, COUNT(DISTINCT o.orderNumber) AS date, orderDate
FROM orders o
LEFT JOIN customers c ON o.customerNumber=c.customerNumber
GROUP BY c.customerNumber, o.orderDate
HAVING date>1"""
pd.read_sql(q,con)
# Out:
#    customerNumber  date   orderDate
# 0             141     2  2005-02-10

# %%
q="""
SELECT customerNumber, orderDate, COUNT(DISTINCT orderNUmber)
FROM orders
GROUP BY customerNumber, orderDate
HAVING COUNT(DISTINCT orderNumber)>1"""
pd.read_sql(q,con)
# Out:
#    customerNumber   orderDate  COUNT(DISTINCT orderNUmber)
# 0             141  2005-02-10                            2

# %% [markdown]
# 6. Create a histogram of orders placed by each customer in 2005.

# %%
q="""
SELECT numOrders, COUNT(customerNumber) AS numberOfCustomers
FROM (
SELECT customerNumber, COUNT(orderNumber) AS numOrders
FROM orders
WHERE strftime('%Y', orderDate) = '2005'
GROUP BY customerNumber
) AS orderCounts
GROUP BY numOrders
ORDER BY numOrders;
"""
pd.read_sql(q,con)
# Out:
#    numOrders  numberOfCustomers
# 0          1                 36
# 1          2                  6
# 2          7                  1
# 3          9                  1

# %% [markdown]
# 7. Compute the ratio of payments for each customer vs. the total of payments.

# %%
q="""
WITH customerpayment AS(
  SELECT c.customerName, c.customerNumber, SUM(p.amount) customer_payment
  FROM customers c
  LEFT JOIN payments p ON c.customerNumber=p.customerNumber
  GROUP BY c.customerName
),
totalpayments AS(
  SELECT SUM(p.amounts) as total_payments
  FROM payments )
SELECT cp.customerNumber, cp.customer_payment/tp.total_payments AS paymentratio
FROM customerssss cp
CROSS JOIN totalpayment tp"""
pd.read_sql(q,con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: totalpayment
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-44-3abf96850cc7> in <cell line: 0>()
#      12 FROM customerpayments cp
#      13 CROSS JOIN totalpayment tp"""
# ---> 14 pd.read_sql(q,con)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
# ...

# %%
q="""
WITH customer_payments AS(
  SELECT c.customerName, SUM(p.amount) AS customerpayment, c.customerNumber
  FROM customers c
  LEFT JOIN payments p ON c.customerNumber=p.customerNumber
  GROUP BY c.customerNumber
), total_payment AS(
  SELECT SUM(p.amount) AS total_payment
  FROM payments p
)
SELECT cp.customerNumber,cp.customerpayment/tp.total_payment AS paymentratio
FROM customer_payments cp
CROSS JOIN total_payment tp """
pd.read_sql(q,con)
# Out:
#      customerNumber  paymentratio
# 0               103      0.002520
# 1               112      0.009056
# 2               114      0.020396
# 3               119      0.013209
# 4               121      0.011772
# ..              ...           ...
# 117             486      0.008779
# 118             487      0.004808
# 119             489      0.003342
# 120             495      0.007403
# 121             496      0.012932
#
# [122 rows x 2 columns]

# %%
q="""
WITH total_payments AS (
    SELECT SUM(p.amount) AS total_payment
    FROM payments p
),
customer_payments AS (
    SELECT c.customerNumber, SUM(p.amount) AS customer_payment
    FROM customers c
    LEFT JOIN payments p ON p.customerNumber = c.customerNumber
    GROUP BY c.customerNumber
)
SELECT cp.customerNumber,
       cp.customer_payment / tp.total_payment AS payment_ratio
FROM customer_payments cp
CROSS JOIN total_payments tp"""

pd.read_sql(q,con)
# Out:
#      customerNumber  payment_ratio
# 0               103       0.002520
# 1               112       0.009056
# 2               114       0.020396
# 3               119       0.013209
# 4               121       0.011772
# ..              ...            ...
# 117             486       0.008779
# 118             487       0.004808
# 119             489       0.003342
# 120             495       0.007403
# 121             496       0.012932
#
# [122 rows x 2 columns]

# %%
q="""
SELECT customerNumber,SUM(amount) OVER(PARTITION BY customerNumber)/SUM(amount)OVER()
FROM payments
"""

pd.read_sql(q,con)
# Out:
#      customerNumber  \
# 0               103
# 1               103
# 2               103
# 3               112
# 4               112
# ..              ...
# 268             495
# 269             495
# 270             496
# 271             496
# 272             496
#
#      SUM(amount) OVER(PARTITION BY customerNumber)/SUM(amount)OVER()
# 0                                             0.002520
# 1                                             0.002520
# 2                                             0.002520
# 3                                             0.009056
# 4                                             0.009056
# ..                                                 ...
# 268                                           0.007403
# 269                                           0.007403
# 270                                           0.012932
# 271                                           0.012932
# 272                                           0.012932
#
# [273 rows x 2 columns]
