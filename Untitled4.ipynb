# %%
import sqlite3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
con = sqlite3.connect("/content/drive/MyDrive/eada material/classic.db")

# %%
q="""
SELECT *
FROM offices
"""
employees=pd.read_sql(q,con)
employees.to_csv("customers.csv", index=False)

# %%
q="""
SELECT*
FROM employees
"""
pd.read_sql(q,con)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
q="""
SELECT lastName, firstName fN
FROM employees
"""
pd.read_sql(q,con)
# Out:
#      lastName        fN
# 0      Murphy     Diane
# 1   Patterson      Mary
# 2    Firrelli      Jeff
# 3   Patterson   William
# 4      Bondur    Gerard
# 5         Bow   Anthony
# 6    Jennings    Leslie
# 7    Thompson    Leslie
# 8    Firrelli     Julie
# 9   Patterson     Steve
# 10      Tseng  Foon Yue
# 11     Vanauf    George
# 12     Bondur      Loui
# 13  Hernandez    Gerard
# 14   Castillo    Pamela
# 15       Bott     Larry
# 16      Jones     Barry
# 17     Fixter      Andy
# 18      Marsh     Peter
# 19       King       Tom
# 20      Nishi      Mami
# 21       Kato   Yoshimi
# 22     Gerard    Martin

# %%
q="""
PRAGMA table_info(employees)
"""
pd.read_sql(q,con)
# Out:
#    cid            name     type  notnull dflt_value  pk
# 0    0  employeeNumber  INTEGER        0       None   0
# 1    1        lastName     TEXT        0       None   0
# 2    2       firstName     TEXT        0       None   0
# 3    3       extension     TEXT        0       None   0
# 4    4           email     TEXT        0       None   0
# 5    5      officeCode  INTEGER        0       None   0
# 6    6       reportsTo     TEXT        0       None   0
# 7    7        jobTitle     TEXT        0       None   0

# %%
q="""
SELECT *
FROM sqlite_master"""
pd.read_sql(q,con)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table     customers     customers         2
# 1  table     employees     employees         7
# 2  table       offices       offices         8
# 3  table  orderdetails  orderdetails         9
# 4  table        orders        orders        33
# 5  table      payments      payments        41
# 6  table  productlines  productlines        45
# 7  table      products      products        46
#
#                                                  sql
# 0  CREATE TABLE "customers" (\n\t"customerNumber"...
# 1  CREATE TABLE "employees" (\n\t"employeeNumber"...
# 2  CREATE TABLE "offices" (\n\t"officeCode"\tINTE...
# 3  CREATE TABLE "orderdetails" (\n\t"orderNumber"...
# 4  CREATE TABLE "orders" (\n\t"orderNumber"\tINTE...
# 5  CREATE TABLE "payments" (\n\t"customerNumber"\...
# 6  CREATE TABLE "productlines" (\n\t"productLine"...
# 7  CREATE TABLE "products" (\n\t"productCode"\tTE...

# %%
q="""
SELECT lastName || "  ," || firstName  NameSurname
FROM employees"""
pd.read_sql(q,con)
# Out:
#             NameSurname
# 0        Murphy  ,Diane
# 1      Patterson  ,Mary
# 2       Firrelli  ,Jeff
# 3   Patterson  ,William
# 4       Bondur  ,Gerard
# 5         Bow  ,Anthony
# 6     Jennings  ,Leslie
# 7     Thompson  ,Leslie
# 8      Firrelli  ,Julie
# 9     Patterson  ,Steve
# 10     Tseng  ,Foon Yue
# 11      Vanauf  ,George
# 12        Bondur  ,Loui
# 13   Hernandez  ,Gerard
# 14    Castillo  ,Pamela
# 15         Bott  ,Larry
# 16        Jones  ,Barry
# 17        Fixter  ,Andy
# 18        Marsh  ,Peter
# 19           King  ,Tom
# 20         Nishi  ,Mami
# 21       Kato  ,Yoshimi
# 22      Gerard  ,Martin

# %%
q="""
SELECT lastName, firstName, email
FROM employees
ORDER BY lastName , firstName DESC"""
pd.read_sql(q,con)
# Out:
#      lastName firstName                            email
# 0      Bondur      Loui     lbondur@classicmodelcars.com
# 1      Bondur    Gerard     gbondur@classicmodelcars.com
# 2        Bott     Larry       lbott@classicmodelcars.com
# 3         Bow   Anthony        abow@classicmodelcars.com
# 4    Castillo    Pamela   pcastillo@classicmodelcars.com
# 5    Firrelli     Julie   jfirrelli@classicmodelcars.com
# 6    Firrelli      Jeff   jfirrelli@classicmodelcars.com
# 7      Fixter      Andy     afixter@classicmodelcars.com
# 8      Gerard    Martin     mgerard@classicmodelcars.com
# 9   Hernandez    Gerard   ghernande@classicmodelcars.com
# 10   Jennings    Leslie   ljennings@classicmodelcars.com
# 11      Jones     Barry      bjones@classicmodelcars.com
# 12       Kato   Yoshimi       ykato@classicmodelcars.com
# 13       King       Tom       tking@classicmodelcars.com
# 14      Marsh     Peter      pmarsh@classicmodelcars.com
# ...

# %%
q="""
SELECT productCode, productName,productLine,productScale, quantityInStock
FROM products
WHERE productScale="1:18"
"""
pd.read_sql(q,con)
# Out:
#    productCode                               productName       productLine  \
# 0     S12_3148                        1969 Corvair Monza      Classic Cars
# 1     S18_1097                    1940 Ford Pickup Truck  Trucks and Buses
# 2     S18_1129                           1993 Mazda RX-7      Classic Cars
# 3     S18_1342                      1937 Lincoln Berline      Vintage Cars
# 4     S18_1367  1936 Mercedes-Benz 500K Special Roadster      Vintage Cars
# 5     S18_1589                     1965 Aston Martin DB5      Classic Cars
# 6     S18_1662               1980s Black Hawk Helicopter            Planes
# 7     S18_1749                  1917 Grand Touring Sedan      Vintage Cars
# 8     S18_1889               1948 Porsche 356-A Roadster      Classic Cars
# 9     S18_1984                          1995 Honda Civic      Classic Cars
# 10    S18_2238            1998 Chrysler Plymouth Prowler      Classic Cars
# ...

# %%
q="""
SELECT productScale, productVendor, productName
FROM products
WHERE productScale="1:18" AND productVendor="Classic Metal Creations"
"""
pd.read_sql(q,con)
# Out:
#   productScale            productVendor                productName
# 0         1:18  Classic Metal Creations      1965 Aston Martin DB5
# 1         1:18  Classic Metal Creations  1957 Corvette Convertible
# 2         1:18  Classic Metal Creations    1956 Porsche 356A Coupe
# 3         1:18  Classic Metal Creations      1961 Chevrolet Impala

# %%
q="""
SELECT productName, productScale,productVendor
FROM products
WHERE productScale="1:18" OR productScale="1:10"
"""
pd.read_sql(q,con)
# Out:
#                                  productName productScale  \
# 0      1969 Harley Davidson Ultimate Chopper         1:10
# 1                   1952 Alpine Renault 1300         1:10
# 2                      1996 Moto Guzzi 1100i         1:10
# 3       2003 Harley-Davidson Eagle Drag Bike         1:10
# 4                        1972 Alfa Romeo GTA         1:10
# 5                     1962 LanciaA Delta 16V         1:10
# 6                         1969 Corvair Monza         1:18
# 7                     1940 Ford Pickup Truck         1:18
# 8                            1993 Mazda RX-7         1:18
# 9                       1937 Lincoln Berline         1:18
# 10  1936 Mercedes-Benz 500K Special Roadster         1:18
# 11                     1965 Aston Martin DB5         1:18
# 12               1980s Black Hawk Helicopter         1:18
# 13                  1917 Grand Touring Sedan         1:18
# 14               1948 Porsche 356-A Roadster         1:18
# ...

# %%
q="""
SELECT productCode, productName,productLine,productScale
FROM products
WHERE productScale IN("1:18",  "1:10")
"""
pd.read_sql(q,con)
# Out:
#    productCode                               productName       productLine  \
# 0     S10_1678     1969 Harley Davidson Ultimate Chopper       Motorcycles
# 1     S10_1949                  1952 Alpine Renault 1300      Classic Cars
# 2     S10_2016                     1996 Moto Guzzi 1100i       Motorcycles
# 3     S10_4698      2003 Harley-Davidson Eagle Drag Bike       Motorcycles
# 4     S10_4757                       1972 Alfa Romeo GTA      Classic Cars
# 5     S10_4962                    1962 LanciaA Delta 16V      Classic Cars
# 6     S12_3148                        1969 Corvair Monza      Classic Cars
# 7     S18_1097                    1940 Ford Pickup Truck  Trucks and Buses
# 8     S18_1129                           1993 Mazda RX-7      Classic Cars
# 9     S18_1342                      1937 Lincoln Berline      Vintage Cars
# 10    S18_1367  1936 Mercedes-Benz 500K Special Roadster      Vintage Cars
# ...

# %%
q="""
SELECT DISTINCT productVendor, productName
FROM products
ORDER BY productName"""
pd.read_sql(q,con)
# Out:
#                  productVendor                          productName
# 0            Red Start Diecast  18th Century Vintage Horse Carriage
# 1     Carousel DieCast Legends                18th century schooner
# 2        Autoart Studio Design               1900s Vintage Bi-Plane
# 3         Unimax Art Galleries              1900s Vintage Tri-Plane
# 4         Unimax Art Galleries                    1903 Ford Model A
# ..                         ...                                  ...
# 105        Studio M Art Models                        The Mayflower
# 106  Welly Diecast Productions                       The Queen Mary
# 107      Autoart Studio Design                The Schooner Bluenose
# 108   Carousel DieCast Legends                          The Titanic
# 109          Red Start Diecast            The USS Constitution Ship
#
# [110 rows x 2 columns]

# %%
q="""
SELECT customerName, creditLimit
FROM customers
WHERE creditLimit BETWEEN 60000 AND 70000
"""
pd.read_sql(q,con)
# Out:
#                     customerName  creditLimit
# 0                Mini Wheels Co.      64600.0
# 1        Clover Collections, Co.      69400.0
# 2       Online Mini Collectables      68700.0
# 3             Enaco Distributors      60300.0
# 4                   Alpha Cognac      61100.0
# 5                Lyon Souveniers      68100.0
# 6           Marseille Mini Autos      65000.0
# 7           Classic Legends Inc.      67500.0
# 8   Australian Collectables, Ltd      60300.0
# 9     Iberia Gift Imports, Corp.      65700.0
# 10      Signal Collectibles Ltd.      60300.0

# %%
q="""
SELECT customerNames
FROM cusomers
LIMIT 10"""
pd.read_sql(q,con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such column: customerNames
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-31-2c3d4f20adec> in <cell line: 0>()
#       3 FROM customers
#       4 LIMIT 10"""
# ----> 5 pd.read_sql(q,con)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
# ...
